# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5, 100)
def f1(x):
    return 2*(x-1)
def f2(x):
    return x

def f(x, l):
    return l[0] * f1(x) + l[1] * f2(x)

# %%
plt.plot(x, f(x, [1,2]))
